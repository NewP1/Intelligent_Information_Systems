# %%
from selenium import webdriver

driver = webdriver.Chrome(r"C:\Users\jaehy\Downloads\driver\chromedriver.exe")
# Out:
# C:\Users\jaehy\AppData\Local\Temp/ipykernel_19416/1756175631.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r"C:\Users\jaehy\Downloads\driver\chromedriver.exe")

# %%
main_url = "https://movie.daum.net/moviedb/grade?movieId=115112"
driver.get(main_url)

# %% [markdown]
# # 1번 영화 리뷰 가져오기

# %% [markdown]
# ## 교수님께서 정해주신 최대 댓글 5000개 미만이기 때문에 전체 댓글을 끝까지 긁어올 수 있도록 더보기를 클릭하도록 했다.
#
# ### 전체 평가 글 1254개

# %%
import time
while True:
    try:
        more_xpath = '//*[@id="alex-area"]/div/div/div/div[3]/div[1]/button'
        driver.find_element('xpath', more_xpath).click()
        time.sleep(3)
    except:
        break

# %% [markdown]
# ## BeautifulSoup 이용하여 위의 Selenium작업이 수행된 페이지를 받아서 원하는 부분을 크롤링

# %%
from bs4 import BeautifulSoup

html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')
evaluations = soup.find_all('div', {'class':'cmt_info'})
# print(evaluations)
evaluation_lists = []
for evaluation in evaluations:
    if evaluation.find('p') is not None:
        comment = evaluation.find('p').text.strip(' \n')
        point = int(evaluation.find('div').text.strip(' \n'))
        if point >= 7:
            label = 'pos'
        else : label = 'neg'
        evaluation_lists.append((comment, label))

# %%
# print(evaluation_lists)

# %% [markdown]
# 평가와 평점을 크롤링 해오면서 평점이 __7점 이상인 평은 긍정 리뷰__로, __7점 미만인 평은 부정 리뷰__로 바로 나눠서 evaluation_lists에 저장되도록 했다.

# %% [markdown]
# ---

# %% [markdown]
# # 2번 워드 클라우드 그리기~

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
okt = Okt()

# %% [markdown]
# 전체 리뷰는 all_comment, 긍정 리뷰는 pos_comment, 부정 리뷰는 neg_comment에 저장하도록 했다.

# %%
all_comment = []
pos_comment = []
neg_comment = []

for comment in evaluation_lists:
    all_comment.append(comment[0])
    if comment[1] == 'pos':
        pos_comment.append(comment[0])
    else:
        neg_comment.append(comment[0])
        
# print(all_comment[:5])

# %% [markdown]
# ### 워드 클라우드를 그리기 위해 각 문장들을 합쳐서 하나의 문장으로 join시키고 명사들만 리스트에 남겼다.
#
# ### 워드 클라우드를 그리기 위해 각 리뷰 리스트들을 Counter를 이용해 개수 파악을 했다.

# %%
all_doc = '\n'.join(all_comment)
all_doc_noun = okt.nouns(all_doc)
all_count = Counter(all_doc_noun)

pos_doc = '\n'.join(pos_comment)
pos_doc_noun = okt.nouns(pos_doc)
pos_count = Counter(pos_doc_noun)

neg_doc = '\n'.join(neg_comment)
neg_doc_noun = okt.nouns(neg_doc)
neg_count = Counter(neg_doc_noun)

wc = WordCloud(background_color='white', max_words=2000, font_path=r'C:\Windows\Fonts\malgun.ttf')

# %% [markdown]
# ## 워드 클라우드
#
# ### - 의미없는 단어 처리하기

# %% [markdown]
# 기본적으로 있을 법한 길이가 2 이상인 단어들은 미리 리스트에 추가해 워드클라우드를 그리는 데에 불필요한 단어들을 지웠다.

# %%
stopword_list = ['진짜', '너무', '바로', '엄청', '정말', '완전','영화', '원작', '손예진', '소지섭']

for short_word in all_count:
    if len(short_word) == 1:
        stopword_list.append(short_word)
        
for stopword in stopword_list:
    if stopword in all_count:
        all_count.pop(stopword)
        
    if stopword in pos_count:
        pos_count.pop(stopword) 
        
    if stopword in neg_count:
        neg_count.pop(stopword)

# %%
wc_all = wc.generate_from_frequencies(all_count)
all_count.most_common(20)
# Out:
# [('연기', 12),
#  ('배우', 10),
#  ('스토리', 8),
#  ('감정', 8),
#  ('리메이크', 7),
#  ('여운', 7),
#  ('감동', 6),
#  ('사랑', 6),
#  ('한국', 5),
#  ('일본', 5),
#  ('때문', 4),
#  ('생각', 4),
#  ('가슴', 4),
#  ('마지막', 4),
#  ('마음', 4),
#  ('감성', 4),
#  ('다시', 4),
#  ('억지', 4),
#  ('버전', 3),
#  ('전혀', 3)]

# %%
plt.figure(figsize=(12,8))
plt.imshow(wc_all, interpolation='bilinear')
plt.show()

# %% [markdown]
# ### 긍정 리뷰 워드 클라우드

# %%
wc_pos = wc.generate_from_frequencies(pos_count)
pos_count.most_common(20)
# Out:
# [('연기', 9),
#  ('배우', 7),
#  ('사랑', 6),
#  ('감정', 6),
#  ('한국', 4),
#  ('일본', 4),
#  ('스토리', 4),
#  ('때문', 4),
#  ('버전', 3),
#  ('대해', 3),
#  ('생각', 3),
#  ('지금', 3),
#  ('가슴', 3),
#  ('다시', 3),
#  ('여운', 3),
#  ('감동', 2),
#  ('먼저', 2),
#  ('깊이', 2),
#  ('한번', 2),
#  ('대한', 2)]

# %%
plt.figure(figsize=(12,8))
plt.imshow(wc_pos, interpolation='bilinear')
plt.show()

# %% [markdown]
# ### 부정 리뷰 워드 클라우드

# %%
wc_neg = wc.generate_from_frequencies(neg_count)
neg_count.most_common(20)
# Out:
# [('리메이크', 5),
#  ('감동', 4),
#  ('스토리', 4),
#  ('여운', 4),
#  ('억지', 4),
#  ('연기', 3),
#  ('처음', 3),
#  ('조합', 3),
#  ('배우', 3),
#  ('감성', 3),
#  ('관객', 3),
#  ('마음', 3),
#  ('전혀', 2),
#  ('집중', 2),
#  ('중간', 2),
#  ('개인', 2),
#  ('마지막', 2),
#  ('코믹', 2),
#  ('내용', 2),
#  ('감정', 2)]

# %%
plt.figure(figsize=(12,8))
plt.imshow(wc_neg, interpolation='bilinear')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 3번 나이브 베이즈

# %% [markdown]
# ### 1번에서 완성시킨 evaluation_lists를 가져와 학습시킨다.

# %%
from nltk.tokenize import word_tokenize
import nltk
use_morph = False

# %%
def pos_tokenize(raw_sent):
    pos_sent = []
    
    sent = okt.pos(raw_sent, norm=True, stem=True)
    
    for tup in sent:
        word, tag = tup[0], tup[1]
        word_tag = word + '/' + tag
        pos_sent.append(word_tag)
    return ' '.join(pos_sent)

# %%
def make_word_dict(train, use_morph=False):
    all_words = set()
    
    for tup in train:
        sent, label = tup[0], tup[1]
        if use_morph: sent = pos_tokenize(sent)
        words = word_tokenize(sent)
        for word in words:
            all_words.add(word)
            
    return all_words

# %%
def make_train_feats(train, all_words, use_morph=False):
    train_features = []
    
    for tup in train:
        sent, label = tup[0], tup[1]
        if use_morph: sent = pos_tokenize(sent)
        words = word_tokenize(sent)
        tmp = {set_word: (set_word in words) for set_word in all_words}
        sent_tup = (tmp, label)
        train_features.append(sent_tup)
        
    return train_features

# %%
# print(evaluation_lists)

# %%
all_words = make_word_dict(evaluation_lists, use_morph)
print(len(all_words))
# print(all_words)
# Out:
# 204

# %%
train_features = make_train_feats(evaluation_lists, all_words, use_morph)
# print(train_features)

# %%
classifier = nltk.NaiveBayesClassifier.train(train_features)
print(classifier)
# Out:
# <nltk.classify.naivebayes.NaiveBayesClassifier object at 0x00000275F23C8C70>

# %%
classifier.show_most_informative_features(200)
# Out:
# Most Informative Features
#                        , = False             neg : pos    =      2.1 : 1.0
#                        . = False             neg : pos    =      1.5 : 1.0
#                        ㅠ = True              neg : pos    =      1.5 : 1.0
#                        것 = True              neg : pos    =      1.5 : 1.0
#                       많이 = True              neg : pos    =      1.5 : 1.0
#                      소지섭 = True              neg : pos    =      1.5 : 1.0
#                        잘 = True              neg : pos    =      1.5 : 1.0
#                        본 = False             neg : pos    =      1.5 : 1.0
#                      사랑의 = False             neg : pos    =      1.5 : 1.0
#                     스토리가 = False             neg : pos    =      1.5 : 1.0
#                      영화를 = False             neg : pos    =      1.5 : 1.0
#                        이 = False             neg : pos    =      1.5 : 1.0
#                      같은데 = False             pos : neg    =      1.5 : 1.0
#                        긴 = False             pos : neg    =      1.5 : 1.0
#                      남우가 = False             pos : neg    =      1.5 : 1.0
#                내취향은전혀아니다 = False             pos : neg    =      1.5 : 1.0
#                      만들긴 = False             pos : neg    =      1.5 : 1.0
#                    못생겼지만 = False             pos : neg    =      1.5 : 1.0
#                       백배 = False             pos : neg    =      1.5 : 1.0
#                     벗어나지 = False             pos : neg    =      1.5 : 1.0
#                       신들 = False             pos : neg    =      1.5 : 1.0
#                     쓸대없이 = False             pos : neg    =      1.5 : 1.0
#                       안됨 = False             pos : neg    =      1.5 : 1.0
#                       않게 = False             pos : neg    =      1.5 : 1.0
#                      어설픈 = False             pos : neg    =      1.5 : 1.0
#                      연기에 = False             pos : neg    =      1.5 : 1.0
#                       원작 = False             pos : neg    =      1.5 : 1.0
#                      원작에 = False             pos : neg    =      1.5 : 1.0
#                      잘했다 = False             pos : neg    =      1.5 : 1.0
#                     재미없이 = False             pos : neg    =      1.5 : 1.0
#                     중간중간 = False             pos : neg    =      1.5 : 1.0
#                       지루 = False             pos : neg    =      1.5 : 1.0
#                      지루한 = False             pos : neg    =      1.5 : 1.0
#                     진부하고 = False             pos : neg    =      1.5 : 1.0
#                      집중이 = False             pos : neg    =      1.5 : 1.0
#                     처음부터 = False             pos : neg    =      1.5 : 1.0
#                       편집 = False             pos : neg    =      1.5 : 1.0
#                        한 = False             pos : neg    =      1.5 : 1.0
#                        . = True              pos : neg    =      1.2 : 1.0
#                        ㅠ = False             pos : neg    =      1.2 : 1.0
#                        것 = False             pos : neg    =      1.2 : 1.0
#                       많이 = False             pos : neg    =      1.2 : 1.0
#                      소지섭 = False             pos : neg    =      1.2 : 1.0
#                        잘 = False             pos : neg    =      1.2 : 1.0
#                        ! = False             neg : pos    =      1.2 : 1.0
#                        ' = False             neg : pos    =      1.2 : 1.0
#                 '손예진'이라는 = False             neg : pos    =      1.2 : 1.0
#                      '지금 = False             neg : pos    =      1.2 : 1.0
#                       .. = False             neg : pos    =      1.2 : 1.0
#                      ... = False             neg : pos    =      1.2 : 1.0
#                     10.0 = False             neg : pos    =      1.2 : 1.0
#                      9.5 = False             neg : pos    =      1.2 : 1.0
#                        : = False             neg : pos    =      1.2 : 1.0
#                       ㅜㅜ = False             neg : pos    =      1.2 : 1.0
#                       가슴 = False             neg : pos    =      1.2 : 1.0
#                     감독님은 = False             neg : pos    =      1.2 : 1.0
#                    감동적이고 = False             neg : pos    =      1.2 : 1.0
#                      감성도 = False             neg : pos    =      1.2 : 1.0
#                       감정 = False             neg : pos    =      1.2 : 1.0
#                      감정이 = False             neg : pos    =      1.2 : 1.0
#                        갑 = False             neg : pos    =      1.2 : 1.0
#                       갑중 = False             neg : pos    =      1.2 : 1.0
#                     같습니다 = False             neg : pos    =      1.2 : 1.0
#                      겹쳐서 = False             neg : pos    =      1.2 : 1.0
#                      곳에서 = False             neg : pos    =      1.2 : 1.0
#                      관심이 = False             neg : pos    =      1.2 : 1.0
#                        그 = False             neg : pos    =      1.2 : 1.0
#                      그때도 = False             neg : pos    =      1.2 : 1.0
#                      그래도 = False             neg : pos    =      1.2 : 1.0
#                      기억이 = False             neg : pos    =      1.2 : 1.0
#                       깊은 = False             neg : pos    =      1.2 : 1.0
#                       깊이 = False             neg : pos    =      1.2 : 1.0
#                    끝장입니다 = False             neg : pos    =      1.2 : 1.0
#                       나는 = False             neg : pos    =      1.2 : 1.0
#                       나를 = False             neg : pos    =      1.2 : 1.0
#                      남는데 = False             neg : pos    =      1.2 : 1.0
#                     남한으로 = False             neg : pos    =      1.2 : 1.0
#                        넘 = False             neg : pos    =      1.2 : 1.0
#                    넘어가야만 = False             neg : pos    =      1.2 : 1.0
#                      넘어갈 = False             neg : pos    =      1.2 : 1.0
#                    누구보다도 = False             neg : pos    =      1.2 : 1.0
#                        는 = False             neg : pos    =      1.2 : 1.0
#                       다른 = False             neg : pos    =      1.2 : 1.0
#                      다쿠지 = False             neg : pos    =      1.2 : 1.0
#                      단순히 = False             neg : pos    =      1.2 : 1.0
#                       대한 = False             neg : pos    =      1.2 : 1.0
#                       대해 = False             neg : pos    =      1.2 : 1.0
#                        든 = False             neg : pos    =      1.2 : 1.0
#                    들여다보지 = False             neg : pos    =      1.2 : 1.0
#                     딱이구요 = False             neg : pos    =      1.2 : 1.0
#                        때 = False             neg : pos    =      1.2 : 1.0
#                       때도 = False             neg : pos    =      1.2 : 1.0
#                     때문인데 = False             neg : pos    =      1.2 : 1.0
#                       때의 = False             neg : pos    =      1.2 : 1.0
#                        또 = False             neg : pos    =      1.2 : 1.0
#                       또한 = False             neg : pos    =      1.2 : 1.0
#                      마음이 = False             neg : pos    =      1.2 : 1.0
#                     마지막에 = False             neg : pos    =      1.2 : 1.0
#                   만나러갑니다 = False             neg : pos    =      1.2 : 1.0
#                     만드셨고 = False             neg : pos    =      1.2 : 1.0
#                     만들었다 = False             neg : pos    =      1.2 : 1.0
#                    맞았습니다 = False             neg : pos    =      1.2 : 1.0
#                        매 = False             neg : pos    =      1.2 : 1.0
#                       먼저 = False             neg : pos    =      1.2 : 1.0
#                      멋있는 = False             neg : pos    =      1.2 : 1.0
#                    명작이기는 = False             neg : pos    =      1.2 : 1.0
#                      못했을 = False             neg : pos    =      1.2 : 1.0
#                       배역 = False             neg : pos    =      1.2 : 1.0
#                      배우가 = False             neg : pos    =      1.2 : 1.0
#                    배우님들은 = False             neg : pos    =      1.2 : 1.0
#                      배우에 = False             neg : pos    =      1.2 : 1.0
#                      버전을 = False             neg : pos    =      1.2 : 1.0
#                      보면서 = False             neg : pos    =      1.2 : 1.0
#                      보셨던 = False             neg : pos    =      1.2 : 1.0
#                     보여졌다 = False             neg : pos    =      1.2 : 1.0
#                     봤습니다 = False             neg : pos    =      1.2 : 1.0
#                      봤었다 = False             neg : pos    =      1.2 : 1.0
#                     북받치는 = False             neg : pos    =      1.2 : 1.0
#                      분들은 = False             neg : pos    =      1.2 : 1.0
#                    불시착에서 = False             neg : pos    =      1.2 : 1.0
#                    사람이라는 = False             neg : pos    =      1.2 : 1.0
#                      생각이 = False             neg : pos    =      1.2 : 1.0
#                     생각하는 = False             neg : pos    =      1.2 : 1.0
#                       생겨 = False             neg : pos    =      1.2 : 1.0
#                      생기고 = False             neg : pos    =      1.2 : 1.0
#                       선에 = False             neg : pos    =      1.2 : 1.0
#                      소설도 = False             neg : pos    =      1.2 : 1.0
#                     소지섭과 = False             neg : pos    =      1.2 : 1.0
#                    소화해내는 = False             neg : pos    =      1.2 : 1.0
#                      손예진 = False             neg : pos    =      1.2 : 1.0
#                    손예진언니 = False             neg : pos    =      1.2 : 1.0
#                     손예진은 = False             neg : pos    =      1.2 : 1.0
#                    손예진이랑 = False             neg : pos    =      1.2 : 1.0
#                        수 = False             neg : pos    =      1.2 : 1.0
#                      수아가 = False             neg : pos    =      1.2 : 1.0
#                       순간 = False             neg : pos    =      1.2 : 1.0
#                       쉽게 = False             neg : pos    =      1.2 : 1.0
#                      스토리 = False             neg : pos    =      1.2 : 1.0
#                   스토리때문에 = False             neg : pos    =      1.2 : 1.0
#                      슬퍼서 = False             neg : pos    =      1.2 : 1.0
#                     슬프냐~ = False             neg : pos    =      1.2 : 1.0
#                       슬픈 = False             neg : pos    =      1.2 : 1.0
#                       아닌 = False             neg : pos    =      1.2 : 1.0
#                    아닐까싶다 = False             neg : pos    =      1.2 : 1.0
#                     아름답다 = False             neg : pos    =      1.2 : 1.0
#                       아빠 = False             neg : pos    =      1.2 : 1.0
#                      아프게 = False             neg : pos    =      1.2 : 1.0
#                     안쓰럽다 = False             neg : pos    =      1.2 : 1.0
#                     애절하게 = False             neg : pos    =      1.2 : 1.0
#                     애절하고 = False             neg : pos    =      1.2 : 1.0
#                       엄마 = False             neg : pos    =      1.2 : 1.0
#                       없고 = False             neg : pos    =      1.2 : 1.0
#                       없는 = False             neg : pos    =      1.2 : 1.0
#                     없습니다 = False             neg : pos    =      1.2 : 1.0
#                     여기까지 = False             neg : pos    =      1.2 : 1.0
#                       연기 = False             neg : pos    =      1.2 : 1.0
#                      연기를 = False             neg : pos    =      1.2 : 1.0
#                       영화 = False             neg : pos    =      1.2 : 1.0
#                     영화에서 = False             neg : pos    =      1.2 : 1.0
#                      예점에 = False             neg : pos    =      1.2 : 1.0
#                     오랜만에 = False             neg : pos    =      1.2 : 1.0
#                     올라오는 = False             neg : pos    =      1.2 : 1.0
#                       완전 = False             neg : pos    =      1.2 : 1.0
#                      왔는데 = False             neg : pos    =      1.2 : 1.0
#                     왜이렇게 = False             neg : pos    =      1.2 : 1.0
#                   우리나라식의 = False             neg : pos    =      1.2 : 1.0
#                     울게되는 = False             neg : pos    =      1.2 : 1.0
#                      울리고 = False             neg : pos    =      1.2 : 1.0
#                     울었네~ = False             neg : pos    =      1.2 : 1.0
#                      울었던 = False             neg : pos    =      1.2 : 1.0
#                     원작과는 = False             neg : pos    =      1.2 : 1.0
#                      원작도 = False             neg : pos    =      1.2 : 1.0
#                      원작을 = False             neg : pos    =      1.2 : 1.0
#                      이쁘고 = False             neg : pos    =      1.2 : 1.0
#                      이장훈 = False             neg : pos    =      1.2 : 1.0
#                      이제야 = False             neg : pos    =      1.2 : 1.0
#                     이치카와 = False             neg : pos    =      1.2 : 1.0
#                       이후 = False             neg : pos    =      1.2 : 1.0
#                       일본 = False             neg : pos    =      1.2 : 1.0
#                      읽어본 = False             neg : pos    =      1.2 : 1.0
#                     잉~~~ = False             neg : pos    =      1.2 : 1.0
#                      작가님 = False             neg : pos    =      1.2 : 1.0
#                       작품 = False             neg : pos    =      1.2 : 1.0
#                       재미 = False             neg : pos    =      1.2 : 1.0
#                       저는 = False             neg : pos    =      1.2 : 1.0
#                       적이 = False             neg : pos    =      1.2 : 1.0
#                       정말 = False             neg : pos    =      1.2 : 1.0
#                     좋네요~ = False             neg : pos    =      1.2 : 1.0
#                    좋아하시고 = False             neg : pos    =      1.2 : 1.0
#                    좋아하시는 = False             neg : pos    =      1.2 : 1.0
#                       지금 = False             neg : pos    =      1.2 : 1.0
#                      지금도 = False             neg : pos    =      1.2 : 1.0
#                      지호가 = False             neg : pos    =      1.2 : 1.0
#                      지호랑 = False             neg : pos    =      1.2 : 1.0
#                       진짜 = False             neg : pos    =      1.2 : 1.0
#                       차마 = False             neg : pos    =      1.2 : 1.0
#                      찾다가 = False             neg : pos    =      1.2 : 1.0
#                       철로 = False             neg : pos    =      1.2 : 1.0
#                     컨셉이랑 = False             neg : pos    =      1.2 : 1.0
#                      터널을 = False             neg : pos    =      1.2 : 1.0

# %%
test_sent = "제발 하지마 ㅠㅠ"

if use_morph: test_sent = pos_tokenize(test_sent)
words = word_tokenize(test_sent)
print(words)
test_feature = {set_word: (set_word in words) for set_word in all_words}
# print(test_feature)

classifier.classify(test_feature)
# Out:
# ['제발', '하지마', 'ㅠㅠ']
# 'neg'
