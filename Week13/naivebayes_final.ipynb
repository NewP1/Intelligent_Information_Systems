# %%
import urllib.request

urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x29a852c5a00>)

# %%
from nltk.tokenize import word_tokenize
import nltk

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
def pos_tokenize(raw_sent):
    pos_sent = []
    
    sent = okt.pos(raw_sent, norm=True, stem=True)
    
    for tup in sent:
        word, tag = tup[0], tup[1]
        word_tag = word + '/' + tag
        pos_sent.append(word_tag)
    return ' '.join(pos_sent)

# %%
def make_word_dict(train, use_morph=False):
    all_words = set()
    
    for tup in train:
        sent, label = tup[0], tup[1]
        if use_morph: sent = pos_tokenize(sent)
        words = word_tokenize(sent)
        for word in words:
            all_words.add(word)
            
    return all_words

# %%
def make_train_feats(train, all_words, use_morph=False):
    train_features = []
    
    for tup in train:
        sent, label = tup[0], tup[1]
        if use_morph: sent = pos_tokenize(sent)
        words = word_tokenize(sent)
        tmp = {set_word: (set_word in words) for set_word in all_words}
        sent_tup = (tmp, label)
        train_features.append(sent_tup)
        
    return train_features

# %%
def load_data(file_path):
    train = []
    count = 0
    
    with open(file_path,'r', encoding='utf-8') as f:
        for line in f.readlines():
            if count == 500: break
            line = line.strip()
            id, doc, label = line.split('\t')
            if label == '1' : label = 'pos'
            elif label == '0': label = 'neg'
            train.append((doc, label))
            count += 1
    return train

# %%
train = load_data('ratings_train.txt')
train[2]
# Out:
# ('흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나', 'pos')

# %%
all_words = make_word_dict(train, use_morph=False)

# %%
train_features = make_train_feats(train, all_words, use_morph=False)
print(train_features[:5])
# Out:
# [({'건지': False, '개연성도': False, "'-": False, '같다는': False, '일으킨': False, '왜그랬으까': False, '보게되었습니다': False, '잔잔하지만': False, '가르엔': False, '크리스토퍼왈츠와': False, '없어도': False, '오시길^^': False, '에릭': False, '코미디와': False, '아이스': False, '청춘': False, '영화수준': False, '상업': False, '5년전꺼다': False, '지네': False, '이기면': False, '동화다운': False, '놀아나는': False, '몸짓으로': False, '이해하는데': False, '괜찮다았던': False, '주인공이': False, '영활': False, '노력하는지를': False, '...': False, '이하늘은': False, '대놓고': False, '이해가': False, '잘봤습니다': False, '몬초가': False, '쌤': False, '들어간다던가': False, '있었다': False, '남을': False, '멋진': False, '보는데': False, '혀짧은': False, '9점': False, '남주인공하는게': False, '아픔을': False, '오늘': False, '하나도': False, '열려있다던지': False, '더대박이였다': False, '쌓고': False, '복수': False, '드라마속에선': False, '내가보기엔': False, '난다': False, '쩔게': False, '별루예요': False, '합시다': False, '지쳐있었는데': False, '극치를': False, '아니다.범죄': False, '모습만': False, '네이버': False, '였다': False, '감독님들': False, '영화뮤지컬영화': False, '봤음에도': False, '나머진다들답답하네요': False, '안나': False, '전개좀': False, '시간가는줄도': False, 'i': False, '세월을': False, '재미있었음': False, '삽니다': False, '다시개봉한건가요': False, '월래익숙한': False, '아니라': False, '빌려온거': False, '어제': False, '배우들이': False, '바라보는': False, '저평가': False, '에볼라바이러스가': False, '전에': False, '대사': False, '명작': False, '호구': False, '감동도': False, '아쉽긴하지만': False, '못따라가는쓰레기영화': False, '남발-': False, '딸린': False, '감독이': False, '멜로영화': False, '그대로': False, '애들좀': False, '그것보단': False, '달팽이가': False, '웃으면서': False, '헐리우드식': False, '멀리': False, '시절을': False, '미스': False, '안나오네요': False, '마코토의': False, '영화보다': False, '몰입이': False, '괜찮음': False, '사랑': False, '느낄수잇엇음': False, '메세지': False, '성격': False, '이드라마는': False, '알겠구만': False, '더럽게': False, '시간과돈을': False, '사람들이': False, '감동을': False, '남는': False, '예쁘네요': False, '한거': False, '한사람에게': False, '잼없음': False, '지나쳐': False, '영화를': False, '보세요': False, '흥행': False, '이론에': False, "''": False, '된영화': False, '기대되는': False, '무서웠어요ㅠ탑은': False, '게임으로나': False, '죽을때': False, '와닿는게': False, '친척형이': False, '1차': False, '내용이': False, '어린시절로': False, '몇': False, '우연히': False, '뭉클해지는': False, '재미있어요': False, '보였습니다': False, '시베리아인가': False, '이냐리투': False, '영화도': False, '행간을': False, '눈으로만보지말고마음으로봐라': False, '남은인생을': False, '거기가서': False, '표절인것은': False, '실제로': False, '감정들을': False, '화끈하게': False, '요즘': False, '순간': False, '횡단보도': False, '푸하하하': False, '하는': False, '더러운유태인이라고': False, '이상함': False, '눈이': False, '또봐도': False, '맛이': False, '미소를': False, '5점대asfgsdlgkbjsjvb': False, '그들도': False, '극장에서': False, '높은': False, "'차이나타운": False, '토르-2': False, '관객은': False, '시노가': False, '장혁은': False, '탁월한': False, '.....': False, '있었지만': False, '했는데': False, '어떤면에서도': False, '시랑을': False, '이상': False, '여자다보니': False, '드래곤': False, '메인': False, '사다코의': False, '위해': False, '질린다이제': False, '평점조절위원회에서': False, '않았으며': False, '최고다': False, '자신이': False, '남기는': False, '영화안봅니다': False, '주는': False, 'ㅡ.ㅡ': False, '녹아든': False, '만감이': False, '수': False, '일탈이': False, '연예인': False, '드럽게못해': False, '출현시켜라이탈리아': False, '이틀전에': False, '오우삼': False, '진부하고말도안됌ㅋㅋ': False, '유쾌하고': False, '고민하면서': False, '별로고': False, '명작도': False, '3박자는': False, '조작하려고하면': False, '잘생겨졌고': False, '거짓평화로': False, '고위': False, '알겠다': False, '갖추지': False, '안간힘': False, '황장군': False, '19세기': False, '상상을': False, '쓸데없이': False, '영화의': False, '알고싶다': False, '빔나가나': False, '말한건': False, '완전': False, '쫌': False, '스스로를': False, '가시다니': False, '벌어지고': False, 'ㅎㅎ': False, '전국민을': False, '봐서': False, '막장도': False, '해피한것만보고싶네요': False, '평범한': False, '무거운': False, '눈': False, '껄끄런': False, '1': False, '사람': False, '비이의': False, '이야기': False, '최고지': False, '쓰면': False, '해석이': False, '1학년생인': False, '한석규한테': False, '갈수록': False, '동화를': False, '들어도': False, '내용': False, '이야기들이': False, '불안하더니만': False, '그녀': False, '힘들게살아오면서': False, '스토리도': False, '당황': False, '졸면서': False, '수작': False, '트리스탄보다': False, 'of': False, '만화라도': False, '중에서도': False, '좋아할듯': False, '3기': False, '깨닫게': False, '없었을까': False, '이런거': False, '즉': Fa ...

# %%
classifier = nltk.NaiveBayesClassifier.train(train_features)

# %%
classifier.show_most_informative_features(200)
# Out:
# Most Informative Features
#                        ; = True              neg : pos    =      8.2 : 1.0
#                        그 = True              pos : neg    =      4.7 : 1.0
#                        수 = True              pos : neg    =      4.7 : 1.0
#                       ㅡㅡ = True              neg : pos    =      4.6 : 1.0
#                        ! = True              pos : neg    =      4.0 : 1.0
#                     스토리도 = True              neg : pos    =      3.9 : 1.0
#                       이거 = True              neg : pos    =      3.9 : 1.0
#                      하나도 = True              neg : pos    =      3.9 : 1.0
#                       없다 = True              neg : pos    =      3.6 : 1.0
#                        ? = True              neg : pos    =      3.6 : 1.0
#                      그리고 = True              neg : pos    =      3.2 : 1.0
#                       이게 = True              neg : pos    =      3.2 : 1.0
#                     .... = True              neg : pos    =      3.0 : 1.0
#                        아 = True              neg : pos    =      2.9 : 1.0
#                      ㅋㅋㅋ = True              pos : neg    =      2.8 : 1.0
#                       보면 = True              pos : neg    =      2.8 : 1.0
#                       싶다 = True              pos : neg    =      2.8 : 1.0
#                       있는 = True              pos : neg    =      2.8 : 1.0
#                       최고 = True              pos : neg    =      2.8 : 1.0
#                      영화가 = True              pos : neg    =      2.5 : 1.0
#                      갈수록 = True              neg : pos    =      2.5 : 1.0
#                       많이 = True              neg : pos    =      2.5 : 1.0
#                      쓰레기 = True              neg : pos    =      2.5 : 1.0
#                      아깝다 = True              neg : pos    =      2.5 : 1.0
#                        안 = True              neg : pos    =      2.5 : 1.0
#                       지금 = True              neg : pos    =      2.5 : 1.0
#                       평점 = True              neg : pos    =      2.5 : 1.0
#                       하나 = True              neg : pos    =      2.5 : 1.0
#                        또 = True              pos : neg    =      2.4 : 1.0
#                       역시 = True              pos : neg    =      2.4 : 1.0
#                       이런 = True              pos : neg    =      2.4 : 1.0
#                       정말 = True              pos : neg    =      2.3 : 1.0
#                      그래서 = True              pos : neg    =      2.2 : 1.0
#                       그런 = True              pos : neg    =      2.2 : 1.0
#                       근데 = True              pos : neg    =      2.2 : 1.0
#                      어떻게 = True              pos : neg    =      2.2 : 1.0
#                      연기는 = True              pos : neg    =      2.2 : 1.0
#                      연기를 = True              pos : neg    =      2.2 : 1.0
#                       있고 = True              pos : neg    =      2.2 : 1.0
#                      재밌게 = True              pos : neg    =      2.2 : 1.0
#                        본 = True              pos : neg    =      2.1 : 1.0
#                       연기 = True              pos : neg    =      2.1 : 1.0
#                        잘 = True              pos : neg    =      2.1 : 1.0
#                        다 = True              neg : pos    =      2.0 : 1.0
#                        왜 = True              neg : pos    =      2.0 : 1.0
#                        더 = True              pos : neg    =      2.0 : 1.0
#                        ' = True              neg : pos    =      1.9 : 1.0
#                       하는 = True              neg : pos    =      1.9 : 1.0
#                       진짜 = True              neg : pos    =      1.9 : 1.0
#                       영화 = True              pos : neg    =      1.8 : 1.0
#                        이 = True              pos : neg    =      1.8 : 1.0
#                      감독의 = True              neg : pos    =      1.8 : 1.0
#                        개 = True              neg : pos    =      1.8 : 1.0
#                       느낌 = True              neg : pos    =      1.8 : 1.0
#                        말 = True              neg : pos    =      1.8 : 1.0
#                       못한 = True              neg : pos    =      1.8 : 1.0
#                       뭐냐 = True              neg : pos    =      1.8 : 1.0
#                        볼 = True              neg : pos    =      1.8 : 1.0
#                       봤다 = True              neg : pos    =      1.8 : 1.0
#                      사람들 = True              neg : pos    =      1.8 : 1.0
#                       아니 = True              neg : pos    =      1.8 : 1.0
#                       아주 = True              neg : pos    =      1.8 : 1.0
#                      연기도 = True              neg : pos    =      1.8 : 1.0
#                      연기력 = True              neg : pos    =      1.8 : 1.0
#                       장면 = True              neg : pos    =      1.8 : 1.0
#                       전개 = True              neg : pos    =      1.8 : 1.0
#                       조금 = True              neg : pos    =      1.8 : 1.0
#                        ( = True              pos : neg    =      1.7 : 1.0
#                        ) = True              pos : neg    =      1.7 : 1.0
#                       ^^ = True              pos : neg    =      1.7 : 1.0
#                        내 = True              pos : neg    =      1.7 : 1.0
#                       내가 = True              pos : neg    =      1.7 : 1.0
#                      영화다 = True              pos : neg    =      1.7 : 1.0
#                        한 = True              pos : neg    =      1.7 : 1.0
#                       이건 = True              neg : pos    =      1.7 : 1.0
#                       그냥 = True              neg : pos    =      1.7 : 1.0
#                       감독 = True              pos : neg    =      1.6 : 1.0
#                       결국 = True              pos : neg    =      1.6 : 1.0
#                        굿 = True              pos : neg    =      1.6 : 1.0
#                      그래도 = True              pos : neg    =      1.6 : 1.0
#                       그저 = True              pos : neg    =      1.6 : 1.0
#                        둘 = True              pos : neg    =      1.6 : 1.0
#                      따뜻한 = True              pos : neg    =      1.6 : 1.0
#                       말이 = True              pos : neg    =      1.6 : 1.0
#                     배우들의 = True              pos : neg    =      1.6 : 1.0
#                     사람들이 = True              pos : neg    =      1.6 : 1.0
#                      설정이 = True              pos : neg    =      1.6 : 1.0
#                       싶은 = True              pos : neg    =      1.6 : 1.0
#                      아직도 = True              pos : neg    =      1.6 : 1.0
#                      없었다 = True              pos : neg    =      1.6 : 1.0
#                      연기가 = True              pos : neg    =      1.6 : 1.0
#                       위한 = True              pos : neg    =      1.6 : 1.0
#                        중 = True              pos : neg    =      1.6 : 1.0
#                      합니다 = True              pos : neg    =      1.6 : 1.0
#                        넘 = True              neg : pos    =      1.5 : 1.0
#                      솔직히 = True              neg : pos    =      1.5 : 1.0
#                      시간이 = True              neg : pos    =      1.5 : 1.0
#                       재미 = True              neg : pos    =      1.5 : 1.0
#                      재미도 = True              neg : pos    =      1.5 : 1.0
#                       보고 = True              pos : neg    =      1.4 : 1.0
#                       ㅋㅋ = True              neg : pos    =      1.4 : 1.0
#                        % = False             pos : label  =      1.3 : 1.0
#                   '버킷리스트 = False             pos : label  =      1.3 : 1.0
#                   '차이나타운 = False             pos : label  =      1.3 : 1.0
#                        + = False             pos : label  =      1.3 : 1.0
#                     ,불륜이 = False             pos : label  =      1.3 : 1.0
#                        - = False             pos : label  =      1.3 : 1.0
#                      -_- = False             pos : label  =      1.3 : 1.0
#                    ..... = False             pos : label  =      1.3 : 1.0
#                   ...... = False             pos : label  =      1.3 : 1.0
#                  ....... = False             pos : label  =      1.3 : 1.0
#                 ........ = False             pos : label  =      1.3 : 1.0
#                      0점은 = False             pos : label  =      1.3 : 1.0
#                        1 = False             pos : label  =      1.3 : 1.0
#                    1/10도 = False             pos : label  =      1.3 : 1.0
#                 100부작이냐고 = False             pos : label  =      1.3 : 1.0
#                    10대들을 = False             pos : label  =      1.3 : 1.0
#                   10살이었음 = False             pos : label  =      1.3 : 1.0
#                   10주년으로 = False             pos : label  =      1.3 : 1.0
#                     10회가 = False             pos : label  =      1.3 : 1.0
#                   114명이네 = False             pos : label  =      1.3 : 1.0
#                 120부작이라니 = False             pos : label  =      1.3 : 1.0
#                    14년도에 = False             pos : label  =      1.3 : 1.0
#                      1위를 = False             pos : label  =      1.3 : 1.0
#                     1이훨나 = False             pos : label  =      1.3 : 1.0
#                    1점남기고 = False             pos : label  =      1.3 : 1.0
#                       1편 = False             pos : label  =      1.3 : 1.0
#                    1학년생인 = False             pos : label  =      1.3 : 1.0
#                      2달이 = False             pos : label  =      1.3 : 1.0
#                     2점부터 = False             pos : label  =      1.3 : 1.0
#                      2편은 = False             pos : label  =      1.3 : 1.0
#                      2편이 = False             pos : label  =      1.3 : 1.0
#                      3류풍 = False             pos : label  =      1.3 : 1.0
#                     3분만에 = False             pos : label  =      1.3 : 1.0
#                     3세부터 = False             pos : label  =      1.3 : 1.0
#                      3점만 = False             pos : label  =      1.3 : 1.0
#                      3점이 = False             pos : label  =      1.3 : 1.0
#                    4대2라니 = False             pos : label  =      1.3 : 1.0
#                       50 = False             pos : label  =      1.3 : 1.0
#                     5개줄게 = False             pos : label  =      1.3 : 1.0
#                    5년전꺼다 = False             pos : label  =      1.3 : 1.0
#       5점대asfgsdlgkbjsjvb = False             pos : label  =      1.3 : 1.0
#                  70회중반인데 = False             pos : label  =      1.3 : 1.0
#                  80~90년대 = False             pos : label  =      1.3 : 1.0
#                8살용영화.ㅋㅋㅋ = False             pos : label  =      1.3 : 1.0
#                      9점대 = False             pos : label  =      1.3 : 1.0
#                        @ = False             pos : label  =      1.3 : 1.0
#                       CG = False             pos : label  =      1.3 : 1.0
#                    CGV에서 = False             pos : label  =      1.3 : 1.0
#                      CG도 = False             pos : label  =      1.3 : 1.0
#                       C급 = False             pos : label  =      1.3 : 1.0
#                     DVD용 = False             pos : label  =      1.3 : 1.0
#                       OO = False             pos : label  =      1.3 : 1.0
#                     OOO기 = False             pos : label  =      1.3 : 1.0
#                OOO기명작이네요 = False             pos : label  =      1.3 : 1.0
#                    OOO영화 = False             pos : label  =      1.3 : 1.0
#                      OO걸 = False             pos : label  =      1.3 : 1.0
#                     OST는 = False             pos : label  =      1.3 : 1.0
#                     OST만 = False             pos : label  =      1.3 : 1.0
#                     What = False             pos : label  =      1.3 : 1.0
#                      for = False             pos : label  =      1.3 : 1.0
#                       is = False             pos : label  =      1.3 : 1.0
#                  mama나가면 = False             pos : label  =      1.3 : 1.0
#                    movie = False             pos : label  =      1.3 : 1.0
#                       of = False             pos : label  =      1.3 : 1.0
#                      the = False             pos : label  =      1.3 : 1.0
#                     this = False             pos : label  =      1.3 : 1.0
#                    trash = False             pos : label  =      1.3 : 1.0
#                     ~머하는 = False             pos : label  =      1.3 : 1.0
#                     ~배우들 = False             pos : label  =      1.3 : 1.0
#                        ㄵ = False             pos : label  =      1.3 : 1.0
#                       ㄷㅔ = False             pos : label  =      1.3 : 1.0
#                        ㅄ = False             pos : label  =      1.3 : 1.0
#                       ㅈㅈ = False             pos : label  =      1.3 : 1.0
#                       ㅉㅉ = False             pos : label  =      1.3 : 1.0
#                 ㅋㅋㅋㅋㅋㅋㅋㅋ = False             pos : label  =      1.3 : 1.0
#         ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ완전 = False             pos : label  =      1.3 : 1.0
#                  ㅋ기네비어역도 = False             pos : label  =      1.3 : 1.0
#                        ㅜ = False             pos : label  =      1.3 : 1.0
#                       ㅜㅜ = False             pos : label  =      1.3 : 1.0
#                        ㅠ = False             pos : label  =      1.3 : 1.0
#                      ㅠ너무 = False             pos : label  =      1.3 : 1.0
#                      ㅡ.ㅡ = False             pos : label  =      1.3 : 1.0
#                    ㅡㅡ잼없음 = False             pos : label  =      1.3 : 1.0
#                       가고 = False             pos : label  =      1.3 : 1.0
#                       가면 = False             pos : label  =      1.3 : 1.0
#                      가문의 = False             pos : label  =      1.3 : 1.0
#                       가발 = False             pos : label  =      1.3 : 1.0
#                     가상하나 = False             pos : label  =      1.3 : 1.0
#                       가장 = False             pos : label  =      1.3 : 1.0
#                      가져가 = False             pos : label  =      1.3 : 1.0
#                      가져온 = False             pos : label  =      1.3 : 1.0
#                    가족도없다 = False             pos : label  =      1.3 : 1.0
#                        간 = False             pos : label  =      1.3 : 1.0
#                      간간히 = False             pos : label  =      1.3 : 1.0
#                       간다 = False             pos : label  =      1.3 : 1.0
#                    간첩색휘들 = False             pos : label  =      1.3 : 1.0
#               갈등-갈등-계~에속 = False             pos : label  =      1.3 : 1.0
#                갈등-화해-감동- = False             pos : label  =      1.3 : 1.0
#                     갈팡질팡 = False             pos : label  =      1.3 : 1.0

# %% [markdown]
# ----------------------
