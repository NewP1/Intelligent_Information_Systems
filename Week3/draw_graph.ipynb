# %%
import matplotlib.pyplot as plt

plt.plot([10,20, 30, 40])
plt.show()

# %%
plt.plot([1, 2, 3, 4], [12, 43, 25, 15])
plt.show()

# %%
plt.title('plotting')

plt.plot([1, 2, 3, 4], [12, 43, 25, 15])
plt.show()

# %%
plt.rc('font', family = 'Malgun Gothic')
plt.title('플로팅')

plt.plot([1, 2, 3, 4], [12, 43, 25, 15])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.rc('font', family = 'Malgun Gothic')
plt.title('범례')

plt.plot([10, 20, 30, 40],color='skyblue', label='범례', linestyle='--')
plt.plot([40, 30, 20, 10],color='pink' ,label='범례2', linestyle='--')

plt.legend(loc=1)
plt.show()
